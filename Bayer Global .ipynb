# %% [markdown]
# ## An analysis on Bayer Global dataset for improvement in Sales

# %% [markdown]
#    This analysis was done on 3 datasets which is CRM data(customer relationship data), SAP data(The financial data of the company) and the VOP data (Voice of customer data).
#    The CRM data displays the company and customer relationship. It gives insight on the various the customers loyalty and how the company is working towards satisfying the customer. The SAP data gives the financial outlines of the company, the units, volumes and financial stand of the company. While the VOP which is an extract from the feedback from customers on their interactions with various part of the company such as Marketing, Sales, and Logistics. It also enriches us with knowledge of the pain point of our customers for easier references and puts us in a position to improve on company services in order to serve our customer best and ward of competitions.

# %% [markdown]
# First thing we do, is import libraries and create a dataframe for each data set, taking a thorough look at each dataframe

# %%
#import important libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading datasets into dataframes and  checking the first five rows of the data 
crm_data= pd.read_excel("C:/Users/HP/Downloads/crm extract copy.xlsx")
crm_data.head()
# Out:
#                                        Name alley Harvest F eadows Verdant   \
# 0                        Serving complexity               2             1.5
# 1              Relationship with sales rep.             3.5               3
# 2                                   Loyalty       High Risk       High Risk
# 3  Market potential (our share of business)             0.5            0.78
# 4                                   Product             Veg             Veg
#
#   rove Green Grow Gardens Orchid  Gardens Serene  Greenscapes Maj  \
# 0               3               3               4               4
# 1               3               4             4.5             4.5
# 2       High Risk           Loyal           Loyal           Loyal
# 3             0.9            0.75            0.97            0.82
# 4             Veg             Veg             Veg             Veg
#
#   Grove Sunflower Growers Botanic Growers Radiant  ... Greenhouses For  \
# ...

# %%
#checking the shape of the crm dataframe
crm_data.shape
# Out:
# (11, 34)

# %%
#check the info of the crm data
crm_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             11 non-null     object
#  1   alley Harvest F  11 non-null     object
#  2   eadows Verdant   11 non-null     object
#  3   rove Green Grow  11 non-null     object
#  4   Gardens Orchid   11 non-null     object
#  5   Gardens Serene   11 non-null     object
#  6   Greenscapes Maj  11 non-null     object
#  7   Grove Sunflower  11 non-null     object
#  8   Growers Botanic  11 non-null     object
#  9   Growers Radiant  11 non-null     object
#  10  lantations Gold  11 non-null     object
#  11  Nurseries Ferti  11 non-null     object
#  12  Nurseries Willo  11 non-null     object
#  13  Nursery Blissfu  11 non-null     object
#  14  Orchards Lush V  11 non-null     object
#  15  Plantations Ter  11 non-null     object
#  16  rchards Eden     11 non-null     object
# ...

# %%
#reading the sap data into a dataframe
sap_data= pd.read_excel("C:/Users/HP/Downloads/extract copy from sap.xlsx")
sap_data.head()
# Out:
#                         Unnamed: 0       Volume sales (units)  \
# 0  Account country code and number  volume sales 2020 (units)
# 1                            a1692                    1270911
# 2                            a3838                     956128
# 3                            a5773                     524595
# 4                            a7153                     742550
#
#                  Unnamed: 2                 Unnamed: 3               Price  \
# 0  volume sales 2021(units)  volume sales 2022 (units)  Price 2020 (units)
# 1                    700438                     882343                 105
# 2                   1232839                     525533                 105
# 3                   1133034                        121                 105
# 4                    898966                     939314                 105
#
#            Unnamed: 5          Unnamed: 6            Unnamed: 7  \
# 0  Price 2021 (units)  Price 2022 (units)  Account country code
# ...

# %%
#check the shape of the data
sap_data.shape
# Out:
# (34, 9)

# %%
#check the info of the sap data
sap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            34 non-null     object
#  1   Volume sales (units)  32 non-null     object
#  2   Unnamed: 2            34 non-null     object
#  3   Unnamed: 3            34 non-null     object
#  4   Price                 34 non-null     object
#  5   Unnamed: 5            34 non-null     object
#  6   Unnamed: 6            34 non-null     object
#  7   Unnamed: 7            34 non-null     object
#  8   Unnamed: 8            34 non-null     object
# dtypes: object(9)
# memory usage: 2.5+ KB

# %%
#read the vop data into dataframe and check the first five observations
vop_data= pd.read_excel("C:/Users/HP/Downloads/copy of vop raw data.xlsx")
vop_data.head()
# Out:
#    Internal ID  Number            StartDate              EndDate  \
# 0  Internal ID  Number           Start Date             End Date
# 1       5222.0     1.0  2022-11-14 23:53:33  2022-11-15 00:03:35
# 2       3838.0     2.0  2022-11-14 22:31:06  2022-11-15 00:49:14
# 3       4515.0     3.0  2022-11-15 01:14:10  2022-11-15 01:25:00
# 4       9302.0     4.0  2022-11-15 03:35:04  2022-11-15 03:49:15
#
#    Duration (in seconds)  Finished                RecordedDate  \
# 0  Duration (in seconds)  Finished               Recorded Date
# 1                  602.0      True  2022-11-15 00:03:36.249000
# 2                 8288.0      True  2022-11-15 00:49:16.056000
# 3                  649.0      True  2022-11-15 01:25:01.626000
# 4                  851.0      True  2022-11-15 03:49:16.159000
#
#                                                  Q2a  \
# 0  Primary Responsibility at Location - Selected ...
# 1                                  Sales / Marketing
# ...

# %%
#check the shape of the data
vop_data.shape
# Out:
# (35, 106)

# %%
#check the info of the data
vop_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Columns: 106 entries, Internal ID to Wave
# dtypes: object(106)
# memory usage: 29.1+ KB

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# We work through each dataset and clean them to ensure high data quality for our analysis.
#
# The first data we work with is customer relationship management data. When the data was imported we saw the names being used as columns for the dataframe it was read into. This does not make the data fit into what we can use to work down our analysis, so the first thing to do is transpose the dataframe to turn the fields (Name) to obserbvations, and the observations (Serving complexity, Relationship with sales rep and others) to fields. This can be seen below

# %%
#Transposing the crm data and reading it into a new dataframe 
df_crm= crm_data.transpose()

# %%
#check the head of the data to ensure our intended code worked
df_crm.head()
# Out:
#                                  0                             1          2   \
# Name             Serving complexity  Relationship with sales rep.    Loyalty
# alley Harvest F                   2                           3.5  High Risk
# eadows Verdant                  1.5                             3  High Risk
# rove Green Grow                   3                             3  High Risk
# Gardens Orchid                    3                             4      Loyal
#
#                                                        3        4   \
# Name             Market potential (our share of business)  Product
# alley Harvest F                                       0.5      Veg
# eadows Verdant                                       0.78      Veg
# rove Green Grow                                       0.9      Veg
# Gardens Orchid                                       0.75      Veg
#
#                              5     6        7                8        9   \
# ...

# %%
#check the info of the data
df_crm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, Name to ardens FreshLea
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       34 non-null     object
#  1   1       34 non-null     object
#  2   2       34 non-null     object
#  3   3       34 non-null     object
#  4   4       34 non-null     object
#  5   5       34 non-null     object
#  6   6       34 non-null     object
#  7   7       34 non-null     object
#  8   8       34 non-null     object
#  9   9       34 non-null     object
#  10  10      34 non-null     object
# dtypes: object(11)
# memory usage: 4.2+ KB

# %% [markdown]
# We can see now that there are 34 entries almost the same as what we have for the SAP data. But our work is not done yet with crm data. It is obvious that the column headers (0, 1, 2, 3 ...) does make it great for analysis. We clean this up but cutting of the top headers of columns and using the second row as the header for the columns.

# %%
#set column names equal to values in row index position 0
df_crm.columns = df_crm.iloc[0]

#remove first row from DataFrame
df_crm = df_crm[1:]

# %%
#check he head of our data
df_crm.head()
# Out:
# Name            Serving complexity Relationship with sales rep.    Loyalty  \
# alley Harvest F                  2                          3.5  High Risk
# eadows Verdant                 1.5                            3  High Risk
# rove Green Grow                  3                            3  High Risk
# Gardens Orchid                   3                            4      Loyal
# Gardens Serene                   4                          4.5      Loyal
#
# Name            Market potential (our share of business) Product  \
# alley Harvest F                                      0.5     Veg
# eadows Verdant                                      0.78     Veg
# rove Green Grow                                      0.9     Veg
# Gardens Orchid                                      0.75     Veg
# Gardens Serene                                      0.97     Veg
#
# Name            Important Code   G2N Account Internal number      P&I  \
# ...

# %%
#check the info  of the crm dataframe
df_crm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, alley Harvest F to ardens FreshLea
# Data columns (total 11 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Serving complexity                        33 non-null     object
#  1   Relationship with sales rep.              33 non-null     object
#  2   Loyalty                                   33 non-null     object
#  3   Market potential (our share of business)  33 non-null     object
#  4   Product                                   33 non-null     object
#  5   Important Code                            33 non-null     object
#  6   G2N                                       33 non-null     object
#  7   Account                                   33 non-null     object
#  8   Internal number                           33 non-null     object
#  9   P&I                                       33 non-null     object
# ...

# %% [markdown]
# Also we can see that data types are not correctly mapped for the columns. For example Market potential (our share of business) is read into the dataframe as object, same for, Serving complexity, Relationship with sales rep., G2N, P&I and Internal number.

# %%
#converting columns from df_crm to float
df_crm[['Serving complexity', "Relationship with sales rep.","Market potential (our share of business)", "G2N", "P&I"]] = df_crm[['Serving complexity', "Relationship with sales rep.","Market potential (our share of business)", "G2N", "P&I"]].astype(float)

# %%
#check the info
df_crm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, alley Harvest F to ardens FreshLea
# Data columns (total 11 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Serving complexity                        33 non-null     float64
#  1   Relationship with sales rep.              33 non-null     float64
#  2   Loyalty                                   33 non-null     object
#  3   Market potential (our share of business)  33 non-null     float64
#  4   Product                                   33 non-null     object
#  5   Important Code                            33 non-null     object
#  6   G2N                                       33 non-null     float64
#  7   Account                                   33 non-null     object
#  8   Internal number                           33 non-null     object
#  9   P&I                                       33 non-null     float64
# ...

# %%
#dropping columns that are not relevant to the scope of our analysis
df_crm.drop(columns=["Product", "Important Code", "Account", "Transactions code"], inplace=True)

# %%
df_crm.head()
# Out:
# Name             Serving complexity  Relationship with sales rep.    Loyalty  \
# alley Harvest F                 2.0                           3.5  High Risk
# eadows Verdant                  1.5                           3.0  High Risk
# rove Green Grow                 3.0                           3.0  High Risk
# Gardens Orchid                  3.0                           4.0      Loyal
# Gardens Serene                  4.0                           4.5      Loyal
#
# Name             Market potential (our share of business)   G2N  \
# alley Harvest F                                      0.50  0.01
# eadows Verdant                                       0.78  0.06
# rove Green Grow                                      0.90  0.12
# Gardens Orchid                                       0.75  0.45
# Gardens Serene                                       0.97  0.31
#
# Name            Internal number      P&I
# alley Harvest F            3838   135.41
# ...

# %%
#checking for missing values in df_crm
df_crm.isnull().sum()
# Out:
# Name
# Serving complexity                          0
# Relationship with sales rep.                0
# Loyalty                                     0
# Market potential (our share of business)    0
# G2N                                         0
# Internal number                             0
# P&I                                         0
# dtype: int64

# %%
#checking for duplicates in df_crm
df_crm.duplicated().isnull().any()
# Out:
# False

# %% [markdown]
# Now we work on the sap data and clean the data to get it ready for analysis. We have first of all split the Account country code and number in Excel sheet to give us two columns Account country code and Internal number. The internal number can be seen as same with the entries from crm data, thus making it a common column for join both tables if need be later on.

# %%
#check the head of the sap data
sap_data.head()
# Out:
#                         Unnamed: 0       Volume sales (units)  \
# 0  Account country code and number  volume sales 2020 (units)
# 1                            a1692                    1270911
# 2                            a3838                     956128
# 3                            a5773                     524595
# 4                            a7153                     742550
#
#                  Unnamed: 2                 Unnamed: 3               Price  \
# 0  volume sales 2021(units)  volume sales 2022 (units)  Price 2020 (units)
# 1                    700438                     882343                 105
# 2                   1232839                     525533                 105
# 3                   1133034                        121                 105
# 4                    898966                     939314                 105
#
#            Unnamed: 5          Unnamed: 6            Unnamed: 7  \
# 0  Price 2021 (units)  Price 2022 (units)  Account country code
# ...

# %%
#check info of sap data
sap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            34 non-null     object
#  1   Volume sales (units)  32 non-null     object
#  2   Unnamed: 2            34 non-null     object
#  3   Unnamed: 3            34 non-null     object
#  4   Price                 34 non-null     object
#  5   Unnamed: 5            34 non-null     object
#  6   Unnamed: 6            34 non-null     object
#  7   Unnamed: 7            34 non-null     object
#  8   Unnamed: 8            34 non-null     object
# dtypes: object(9)
# memory usage: 2.5+ KB

# %% [markdown]
# Now, we apply the same technique to remove the unwanted column headers of the sap data

# %%
#set column names equal to values in row index position 0
sap_data.columns = sap_data.iloc[0]

#remove first row from DataFrame
sap_data = sap_data[1:]

# %%
#check the head of sap data
sap_data.head()
# Out:
# 0 Account country code and number volume sales 2020 (units)  \
# 1                           a1692                   1270911
# 2                           a3838                    956128
# 3                           a5773                    524595
# 4                           a7153                    742550
# 5                           a2930                   1271494
#
# 0 volume sales 2021(units) volume sales 2022 (units) Price 2020 (units)  \
# 1                   700438                    882343                105
# 2                  1232839                    525533                105
# 3                  1133034                       121                105
# 4                   898966                    939314                105
# 5                  1235923                    839606                105
#
# 0 Price 2021 (units) Price 2022 (units) Account country code Internal number
# 1                105                108                    a            1692
# ...

# %%
#check info of the sap data 
sap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 1 to 33
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Account country code and number  33 non-null     object
#  1   volume sales 2020 (units)        31 non-null     object
#  2   volume sales 2021(units)         33 non-null     object
#  3   volume sales 2022 (units)        33 non-null     object
#  4   Price 2020 (units)               33 non-null     object
#  5   Price 2021 (units)               33 non-null     object
#  6   Price 2022 (units)               33 non-null     object
#  7   Account country code             33 non-null     object
#  8   Internal number                  33 non-null     object
# dtypes: object(9)
# memory usage: 2.4+ KB

# %%
#converting columns from sap_data to float
sap_data[['volume sales 2020 (units)', "volume sales 2021(units)","volume sales 2022 (units)", "Price 2020 (units)", "Price 2021 (units)","Price 2022 (units)"]]  = sap_data[['volume sales 2020 (units)', "volume sales 2021(units)","volume sales 2022 (units)", "Price 2020 (units)", "Price 2021 (units)","Price 2022 (units)"]].astype(float)

# %%
sap_data.drop(columns=["Account country code and number", "Account country code"], inplace=True)

# %%
#check the head
sap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 1 to 33
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   volume sales 2020 (units)  31 non-null     float64
#  1   volume sales 2021(units)   33 non-null     float64
#  2   volume sales 2022 (units)  33 non-null     float64
#  3   Price 2020 (units)         33 non-null     float64
#  4   Price 2021 (units)         33 non-null     float64
#  5   Price 2022 (units)         33 non-null     float64
#  6   Internal number            33 non-null     object
# dtypes: float64(6), object(1)
# memory usage: 1.9+ KB

# %%
#checking for missing values in sap_data
sap_data.isnull().sum()
# Out:
# 0
# volume sales 2020 (units)    2
# volume sales 2021(units)     0
# volume sales 2022 (units)    0
# Price 2020 (units)           0
# Price 2021 (units)           0
# Price 2022 (units)           0
# Internal number              0
# dtype: int64

# %% [markdown]
# From our data observation, Volume sales 2020 (units) has two missing values. This is because the customers are new customers and only joined from 2021 where the had volumes sales sold. Thus we fill the null with 0

# %%
#fill null values with 0
df_sap= sap_data.fillna(0)

# %%
#check the info of df_sap
df_sap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 1 to 33
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   volume sales 2020 (units)  33 non-null     float64
#  1   volume sales 2021(units)   33 non-null     float64
#  2   volume sales 2022 (units)  33 non-null     float64
#  3   Price 2020 (units)         33 non-null     float64
#  4   Price 2021 (units)         33 non-null     float64
#  5   Price 2022 (units)         33 non-null     float64
#  6   Internal number            33 non-null     int64
# dtypes: float64(6), int64(1)
# memory usage: 1.9 KB

# %%
#check the first 20 rows of df_sap
df_sap.head(20)
# Out:
# 0   volume sales 2020 (units)  volume sales 2021(units)  \
# 1                1.270911e+06              7.004380e+05
# 2                9.561280e+05              1.232839e+06
# 3                5.245950e+05              1.133034e+06
# 4                7.425500e+05              8.989660e+05
# 5                1.271494e+06              1.235923e+06
# 6                1.311920e+06              1.399160e+06
# 7                1.272385e+06              6.483860e+05
# 8                9.808630e+05              1.201192e+06
# 9                5.426280e+05              7.745970e+05
# 10               2.390099e+05              1.185490e+05
# 11               0.000000e+00              1.515000e+04
# 12               1.327838e+06              6.436360e+05
# 13               5.217880e+05              1.287610e+06
# 14               6.738700e+05              6.122510e+05
# 15               3.335956e+06              1.199400e+06
# 16               3.324987e+05              1.786186e+05
# ...

# %%
#checking for duplicates in sap data
df_sap.duplicated().isnull().any()
# Out:
# False

# %% [markdown]
# Now we take a look at the VOP data which is an extract of the feedback from our survey/interview with our customers

# %%
vop_data.head()
# Out:
#    Internal ID  Number            StartDate              EndDate  \
# 0  Internal ID  Number           Start Date             End Date
# 1       5222.0     1.0  2022-11-14 23:53:33  2022-11-15 00:03:35
# 2       3838.0     2.0  2022-11-14 22:31:06  2022-11-15 00:49:14
# 3       4515.0     3.0  2022-11-15 01:14:10  2022-11-15 01:25:00
# 4       9302.0     4.0  2022-11-15 03:35:04  2022-11-15 03:49:15
#
#    Duration (in seconds)  Finished                RecordedDate  \
# 0  Duration (in seconds)  Finished               Recorded Date
# 1                  602.0      True  2022-11-15 00:03:36.249000
# 2                 8288.0      True  2022-11-15 00:49:16.056000
# 3                  649.0      True  2022-11-15 01:25:01.626000
# 4                  851.0      True  2022-11-15 03:49:16.159000
#
#                                                  Q2a  \
# 0  Primary Responsibility at Location - Selected ...
# 1                                  Sales / Marketing
# ...

# %%
#checking for duplicates in vop data
vop_data.duplicated().isnull().any()
# Out:
# False

# %%
#checking for missing values in vop_data
vop_data.isnull().sum()
# Out:
# Internal ID                                                                           1
# Number                                                                                0
# StartDate                                                                             0
# EndDate                                                                               0
# Duration (in seconds)                                                                 0
#                                                                                      ..
# Digital Tools EN                                                                     30
# How could Bayer help you provide the best experience to your farmer custome... EN    10
# Sub_Region                                                                           33
# Unified iQ                                                                           11
# Wave                                                                                 34
# ...

# %% [markdown]
# We calculate the percentage of null values in the each columns and drop the columns with over 50% null values

# %%
(vop_data.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# Wave               97.142857
# Unnamed: 93        97.142857
# Account Owner      94.285714
# Q27- ANZ Only_2    94.285714
# Q27- ANZ Only_3    94.285714
#                      ...
# Survey Name         0.000000
# SC1                 0.000000
# StartDate           0.000000
# SC0                 0.000000
# Q2a                 0.000000
# Length: 106, dtype: float64

# %%
#set column names equal to values in row index position 0
vop_data.columns = vop_data.iloc[0]

#remove first row from DataFrame
vop_data = vop_data[1:]

# %%
#check the head of the vop data after removing the first headers as column names 
vop_data.head()
# Out:
# 0 Internal ID Number           Start Date             End Date  \
# 1      5222.0    1.0  2022-11-14 23:53:33  2022-11-15 00:03:35
# 2      3838.0    2.0  2022-11-14 22:31:06  2022-11-15 00:49:14
# 3      4515.0    3.0  2022-11-15 01:14:10  2022-11-15 01:25:00
# 4      9302.0    4.0  2022-11-15 03:35:04  2022-11-15 03:49:15
# 5      7153.0    5.0  2022-11-15 11:47:52  2022-11-15 11:56:58
#
# 0 Duration (in seconds) Finished               Recorded Date  \
# 1                 602.0     True  2022-11-15 00:03:36.249000
# 2                8288.0     True  2022-11-15 00:49:16.056000
# 3                 649.0     True  2022-11-15 01:25:01.626000
# 4                 851.0     True  2022-11-15 03:49:16.159000
# 5                 546.0     True  2022-11-15 11:57:00.709000
#
# 0 Primary Responsibility at Location - Selected Choice  \
# 1                                  Sales / Marketing
# 2                                  Sales / Marketing
# ...

# %%
#check info of vop data
vop_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 1 to 34
# Columns: 106 entries, Internal ID to Wave
# dtypes: object(106)
# memory usage: 28.3+ KB

# %% [markdown]
# ### Data Validation

# %% [markdown]
# Describe every process and changes made on the data given
#
#
# #### Data assesment
# 1. Checked the shape of the dataframe
# 2. Generated an overview of the dataframe
# 3. Checked the datatypes and converted to right data types
# 4. Checked for duplicates
# 5. Checked the data for null values
# 6. Transpose data to turn rows to columns and vice versa
# 7. Dropped coluns that are not relevant to the analysis
# 8. Set the second rows as new column headers

# %% [markdown]
# #### Observation
#
# These are my observations from the datasets given
# 1. Customer Relationship Management data had 11 entries or observations and 34 filed which I later transposedd the data to give 34 entries and 11 fields. The System, Applications and Product data has 34 entries and 7 columns, while the VoP data has 34 entries and 106 columns.
# 2. There are 22 customers who have been doing business with the company for 15 yaers +, 4 customers also working with the company for 10-14years, and another four customer also for 4-9years, and the other 1-3years. So it can be deduced that the vast majority of our customers are here for a longtime doing business with us.

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# To get better information from the customer relationship management and sap data, we join both dataframe together.

# %%
#merge dataframes crm and sap data based on common internal number
merged_crm_sap_df = pd.merge(df_crm, df_sap, left_on='Internal number', right_on='Internal number', how='inner')
merged_crm_sap_df.drop_duplicates()
merged_crm_sap_df.head()
# Out:
#    Serving complexity  Relationship with sales rep.    Loyalty  \
# 0                 2.0                           3.5  High Risk
# 1                 1.5                           3.0  High Risk
# 2                 3.0                           3.0  High Risk
# 3                 3.0                           4.0      Loyal
# 4                 4.0                           4.5      Loyal
#
#    Market potential (our share of business)   G2N Internal number      P&I  \
# 0                                      0.50  0.01            3838   135.41
# 1                                      0.78  0.06            2930   695.70
# 2                                      0.90  0.12            5222  1291.92
# 3                                      0.75  0.45            8724  5187.15
# 4                                      0.97  0.31            1170  3683.42
#
#    volume sales 2020 (units)  volume sales 2021(units)  \
# 0               9.561280e+05              1.232839e+06
# ...

# %%
merged_crm_sap_df.head(20)
# Out:
#     Serving complexity  Relationship with sales rep.    Loyalty  \
# 0                  2.0                           3.5  High Risk
# 1                  1.5                           3.0  High Risk
# 2                  3.0                           3.0  High Risk
# 3                  3.0                           4.0      Loyal
# 4                  4.0                           4.5      Loyal
# 5                  4.0                           4.5      Loyal
# 6                  5.0                           4.5      Loyal
# 7                  4.0                           4.5      Loyal
# 8                  5.0                           4.5      Loyal
# 9                  4.0                           3.0      Loyal
# 10                 5.0                           5.0      Loyal
# 11                 1.0                           1.0      Loyal
# 12                 4.0                           5.0      Loyal
# 13                 4.5                           2.0      Loyal
# ...

# %% [markdown]
# We can see from the head of the merged data frame, that the former null values which we filled to zero, that the customer who had null as the sales for 2020 meets our assumptions of being New customers

# %%
merged_crm_sap_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 13 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Serving complexity                        33 non-null     float64
#  1   Relationship with sales rep.              33 non-null     float64
#  2   Loyalty                                   33 non-null     object
#  3   Market potential (our share of business)  33 non-null     float64
#  4   G2N                                       33 non-null     float64
#  5   Internal number                           33 non-null     object
#  6   P&I                                       33 non-null     float64
#  7   volume sales 2020 (units)                 33 non-null     float64
#  8   volume sales 2021(units)                  33 non-null     float64
#  9   volume sales 2022 (units)                 33 non-null     float64
# ...

# %%
#check for null values
merged_crm_sap_df.isnull().sum()
# Out:
# Serving complexity                          0
# Relationship with sales rep.                0
# Loyalty                                     0
# Market potential (our share of business)    0
# G2N                                         0
# Internal number                             0
# P&I                                         0
# volume sales 2020 (units)                   0
# volume sales 2021(units)                    0
# volume sales 2022 (units)                   0
# Price 2020 (units)                          0
# Price 2021 (units)                          0
# Price 2022 (units)                          0
# dtype: int64

# %%
#calculating the value counts of loyalty of dataframe
loyalty_counts=(merged_crm_sap_df.Loyalty.value_counts())
print(loyalty_counts)

#visualizing the loyalty counts using seaborn
plt.figure(figsize=(12,6))
p = sns.countplot(data=merged_crm_sap_df, x="Loyalty"),
plt.xlabel("Loyalty"),
plt.ylabel("Frequency"),
plt.title("The Frequency counts of our customers Loyalty")
plt.show()
# Out:
# Reluctant     14
# Loyal         13
# High Risk      3
# New            2
# Vulnerable     1
# Name: Loyalty, dtype: int64

# %%
merged_crm_sap_df.describe()
# Out:
#        Serving complexity  Relationship with sales rep.  \
# count           33.000000                     33.000000
# mean             3.272727                      3.848485
# std              1.173209                      1.169167
# min              1.000000                      1.000000
# 25%              2.500000                      3.000000
# 50%              3.500000                      4.000000
# 75%              4.000000                      4.500000
# max              5.000000                      5.000000
#
#        Market potential (our share of business)        G2N          P&I  \
# count                                 33.000000  33.000000    33.000000
# mean                                   0.597273   0.203333  2491.539697
# std                                    0.259100   0.128152  1602.083601
# min                                    0.020000   0.010000   135.410000
# 25%                                    0.490000   0.110000  1310.200000
# ...

# %%
# Compute the correlation coefficient for all column pairs
plt.figure(figsize=(20,8))
corrMatrix = merged_crm_sap_df.corr()

# Plot the correlation coefficient for all column pairs
sns.heatmap(corrMatrix, annot=True,linewidths=.2, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %%
#we plot a scatter plot to check the correlation of P&I and G2N
plt.scatter(merged_crm_sap_df["P&I"], merged_crm_sap_df["G2N"], c ="blue")
plt.xlabel("P&I"),
plt.ylabel("G2N"),
plt.title("Scatter plot showing the correlation of G2N and P&I")
# To show the plot
plt.show()

# %% [markdown]
# G2N  is  a metric we like discounts and can change depending on the scale of purchase, or if the customer pays in advance. This often used to build customer relationship. While P&I are incensitives on customer planning to support marketing, promote products etc. From our visualization above we can deduce that the G2N and P&I are very much correlated.

# %% [markdown]
# Let's check the loyaltys and see how the P&I are spent on the loyalty and also the G2N

# %% [markdown]
# From the chart above we can see that a larger amount of our customers are in the reluctant stage of loyalty. This should be one of our focus areas, converting these reluctant customers to loyal customers. Looking at the graph of average G2N against Loyalty and average P&I against Loyalty, we can see that High risk customers get a low G2N and low P&I allocation. So if this (G2N) shows how the company keep customers and build relationship then, the low G2N allocation is a strong reason for customers being at the High risk, Vulnerable(soon to be high) and Reluctant stage of Loyalty to the company

# %%
plt.scatter(merged_crm_sap_df["Market potential (our share of business)"], merged_crm_sap_df["G2N"], c ="blue")
plt.xlabel("Market potential (our share of business)"),
plt.ylabel("G2N"),
plt.title("Scatter plot showing the correlation of G2N and Market potential (our share of business)")
# To show the plot
plt.show()

# %%
plt.scatter(merged_crm_sap_df["Market potential (our share of business)"], merged_crm_sap_df["P&I"], c ="blue")
plt.xlabel("Market potential (our share of business)"),
plt.ylabel("P&I"),
plt.title("Scatter plot showing the correlation of G2N and Market potential (our share of business)")
# To show the plot
plt.show()

# %% [markdown]
# These scatter plots of G2N and P&I against Market potentials (our share of the business) shows somewhat how there is a correlation between these metrics which is normal, because with the customer support and marketing development amidst other perks of our company, we tend to invest more of our shares.

# %% [markdown]
# ### Key Peforming Metrics

# %% [markdown]
# #### Sales Revenue

# %% [markdown]
# First step in our calculations is to total sales made and building up from there

# %%
#calculating the total sales made for each year
merged_crm_sap_df["Sales made 2020"] = merged_crm_sap_df["volume sales 2020 (units)"] * merged_crm_sap_df["Price 2020 (units)"]
merged_crm_sap_df["Sales made 2021"] = merged_crm_sap_df["volume sales 2021(units)"] * merged_crm_sap_df["Price 2021 (units)"]
merged_crm_sap_df["Sales made 2022"] = merged_crm_sap_df["volume sales 2022 (units)"] * merged_crm_sap_df["Price 2022 (units)"]

# %%
#check the head of merged_crm_sap_df
merged_crm_sap_df.head()
# Out:
#    Serving complexity  Relationship with sales rep.    Loyalty  \
# 0                 2.0                           3.5  High Risk
# 1                 1.5                           3.0  High Risk
# 2                 3.0                           3.0  High Risk
# 3                 3.0                           4.0      Loyal
# 4                 4.0                           4.5      Loyal
#
#    Market potential (our share of business)   G2N Internal number      P&I  \
# 0                                      0.50  0.01            3838   135.41
# 1                                      0.78  0.06            2930   695.70
# 2                                      0.90  0.12            5222  1291.92
# 3                                      0.75  0.45            8724  5187.15
# 4                                      0.97  0.31            1170  3683.42
#
#    volume sales 2020 (units)  volume sales 2021(units)  \
# 0               9.561280e+05              1.232839e+06
# ...

# %% [markdown]
# Since G2N and P&I are both expenses from our brand, we subtract them from the sales made for each year

# %%
#Revenue from sales after G2N 
merged_crm_sap_df["G2N 2020"] = merged_crm_sap_df["Sales made 2020"] * merged_crm_sap_df["G2N"]
merged_crm_sap_df["G2N 2021"] = merged_crm_sap_df["Sales made 2021"] * merged_crm_sap_df["G2N"]
merged_crm_sap_df["G2N 2022"] = merged_crm_sap_df["Sales made 2022"] * merged_crm_sap_df["G2N"]

# %%
#check head of data
merged_crm_sap_df.head()
# Out:
#    Serving complexity  Relationship with sales rep.    Loyalty  \
# 0                 2.0                           3.5  High Risk
# 1                 1.5                           3.0  High Risk
# 2                 3.0                           3.0  High Risk
# 3                 3.0                           4.0      Loyal
# 4                 4.0                           4.5      Loyal
#
#    Market potential (our share of business)   G2N Internal number      P&I  \
# 0                                      0.50  0.01            3838   135.41
# 1                                      0.78  0.06            2930   695.70
# 2                                      0.90  0.12            5222  1291.92
# 3                                      0.75  0.45            8724  5187.15
# 4                                      0.97  0.31            1170  3683.42
#
#    volume sales 2020 (units)  volume sales 2021(units)  \
# 0               9.561280e+05              1.232839e+06
# ...

# %%
#Total revenue from sales for each year
merged_crm_sap_df["Total revenue sales 2020"] = merged_crm_sap_df["Sales made 2020"] - (merged_crm_sap_df["G2N 2020"] + merged_crm_sap_df["P&I"])
merged_crm_sap_df["Total revenue sales 2021"] = merged_crm_sap_df["Sales made 2021"] - (merged_crm_sap_df["G2N 2021"] + merged_crm_sap_df["P&I"])
merged_crm_sap_df["Total revenue sales 2022"] = merged_crm_sap_df["Sales made 2022"] - (merged_crm_sap_df["G2N 2022"] + merged_crm_sap_df["P&I"])

# %%
#checking the head of the data
merged_crm_sap_df.head()
# Out:
#    Serving complexity  Relationship with sales rep.    Loyalty  \
# 0                 2.0                           3.5  High Risk
# 1                 1.5                           3.0  High Risk
# 2                 3.0                           3.0  High Risk
# 3                 3.0                           4.0      Loyal
# 4                 4.0                           4.5      Loyal
#
#    Market potential (our share of business)   G2N Internal number      P&I  \
# 0                                      0.50  0.01            3838   135.41
# 1                                      0.78  0.06            2930   695.70
# 2                                      0.90  0.12            5222  1291.92
# 3                                      0.75  0.45            8724  5187.15
# 4                                      0.97  0.31            1170  3683.42
#
#    volume sales 2020 (units)  volume sales 2021(units)  \
# 0               9.561280e+05              1.232839e+06
# ...

# %% [markdown]
# Now we can calculate the total revenue gotten from sales in each year

# %%
#calculating the revenue for 2020
revenue_2020= merged_crm_sap_df["Total revenue sales 2020"].sum().round(2)
print(f"The Revenue generated in 2020 through sales is ${revenue_2020}")
# Out:
# The Revenue generated in 2020 through sales is $2717962091.02

# %%
#calculating the revenue for 2021
revenue_2021= merged_crm_sap_df["Total revenue sales 2021"].sum().round(2)
print(f"The Revenue generated in 2021 through sales is ${revenue_2021}")
# Out:
# The Revenue generated in 2021 through sales is $2347074945.49

# %%
#calculating the revenue for 2022
revenue_2022= merged_crm_sap_df["Total revenue sales 2022"].sum().round(2)
print(f"The Revenue generated in 2022 through sales is ${revenue_2022}")
# Out:
# The Revenue generated in 2022 through sales is $2647572167.95

# %% [markdown]
# From the calculations above, we can see that there is a gradual decrease in the revenue generated from sales. This can be tied to the huge reudction in purchases from our high risk and vulnerable customers and our reluctant customers not improving their purchases

# %% [markdown]
# Also with this calculations above we can measure the first Key performing metric for the sales team which is Sales revenue and comparing the values we can see that the sales revenue decrease over the years from 2020 to 2022.

# %% [markdown]
# #### Sales Growth

# %% [markdown]
# This metric is found by calculating the percentage increase or decrease in sales

# %%
sales_percent_20_21 = (((revenue_2021  - revenue_2020)/ revenue_2020)*100).round(1)
print(f"The Percentage growth in sales from 2020 to 2021 is {sales_percent_20_21}%")
# Out:
# The Percentage growth in sales from 2020 to 2021 is -13.6%

# %%
sales_percent_21_22 = (((revenue_2022  - revenue_2021)/ revenue_2021)*100).round(1)
print(f"The Percentage growth in sales from 2021 to 2022 is {sales_percent_21_22}%")
# Out:
# The Percentage growth in sales from 2021 to 2022 is 12.8%

# %% [markdown]
# We calculate the percentage growth in sales over the 3 year period

# %%
sales_percent_20_22 = (((revenue_2022  - revenue_2020)/ revenue_2020)*100).round(1)
print(f"The Percentage growth in sales from 2020 to 2022 is {sales_percent_20_22}%")
# Out:
# The Percentage growth in sales from 2020 to 2022 is -2.6%
